# %%
class DisjointSet:

	_disjoint_set = list()

	def __init__(self, init_arr):
		self._disjoint_set = []
		if init_arr:
			for item in list(set(init_arr)):
				self._disjoint_set.append([item])

	def _find_index(self, elem):
		for item in self._disjoint_set:
			if elem in item:
				return self._disjoint_set.index(item)
		return None

	def find(self, elem):
		for item in self._disjoint_set:
			if elem in item:
				return self._disjoint_set[self._disjoint_set.index(item)]
		return None
	
	def union(self,elem1, elem2):
		index_elem1 = self._find_index(elem1)
		index_elem2 = self._find_index(elem2)
		if index_elem1 != index_elem2 and index_elem1 is not None and index_elem2 is not None:
			self._disjoint_set[index_elem2] = self._disjoint_set[index_elem2]+self._disjoint_set[index_elem1]
			del self._disjoint_set[index_elem1]
		return self._disjoint_set
		
	def get(self):
		return self._disjoint_set

# %%
def swap(a, i, j):
  ab=a[int(i)]
  a[int(i)]=a[int(j)]
  a[int(j)]=ab
  
#   a[i], a[j] = a[j], a[i]
  
def is_heap(a):
  n = 0
  m = 0
  while True:
    for i in [0, 1]:
      m += 1
      if m >= len(a):
        return True
      if a[m] > a[n]:
        return False
    n += 1
    
def sift_down(a, n, max):
  while True:
    biggest = n
    c1 = int(2*n + 1)
    c2 = int(c1 + 1)
    for c in (c1,c2):
      if c < max and a[c] > a[int(biggest)]:
        biggest = c
    if biggest == n:
      return
    swap(a, n, biggest)
    n = biggest

def heapify(a):
  i = len(a) / 2 - 1
  max = len(a)
  while i >= 0:
    sift_down(a, i, max)
    i -= 1

def heapsort(a):
  heapify(a)
  j = len(a) - 1
  while j > 0:
    swap(a, 0, j)
    sift_down(a, 0, j)
    j -= 1

a = [4,8,8,11,7,4,2,9,14,10,2,1,6,7]
heapsort(a)
print (a)
# Out:
# [1, 2, 2, 4, 4, 6, 7, 7, 8, 8, 9, 10, 11, 14]

# %%
node_num=int(input())  
edge_num = int (input())
a=[""]*edge_num

for i in range(len(a)):
  a[i] = input()
  a[i] = a[i].split()
  a[i][0]=int(a[i][0])
  a[i][1]=int(a[i][1])
  a[i][2]=int(a[i][2])

w=[""]*edge_num
ow=[""]*edge_num
for i in range(len(w)):
  w[i]=a[i][2]         # "ow"  orignal weight           # "w" after heap sort
heapsort(w)
for i in range(len(w)):
  ow[i]=a[i][2]

print("w=",w)
print("ow=",ow)
# if __name__=='__main__':
#   li=[b,c]
#   test_set = DisjointSet(li)
#   test_set.get()
# Out:
# 9
# 14
# 1 2 4
# 1 8 8
# 2 3 8
# 2 8 11
# 3 4 7
# 3 6 4
# 3 9 2
# 4 5 9
# 4 6 14
# 5 6 10
# 6 7 2
# 7 8 1
# 7 9 6
# 8 9 7
# w= [1, 2, 2, 4, 4, 6, 7, 7, 8, 8, 9, 10, 11, 14]
# ow= [4, 8, 8, 11, 7, 4, 2, 9, 14, 10, 2, 1, 6, 7]

# %%
if __name__=='__main__':
  Output=0
  li=[""]*node_num
  symbol=[0]*edge_num
  
  for i in range(node_num):
    li[i]=i+1
  test_set_node = DisjointSet(li)
  print("test_set_node",test_set_node)
  
#   test_set_ow= DisjointSet(ow)
  print("w=",w)
  print("ow=",ow)

  for j in range(edge_num):
    
    print("max_w=",w[edge_num-j-1])
    for i in range(len(ow)):
      if ow[i]==w[edge_num-j-1]:
        
        index=i
        print("a[index][0]=",a[index][0])
        print("a[index][1]=",a[index][1])
        if test_set_node.find(a[index][0]) != test_set_node.find(a[index][1]) and symbol[i]==0:
          symbol[i]=1
          print("ow[i]",ow[i])
          Output += ow[i]
          
          print("test_set_node",test_set_node.union(a[i][0],a[i][1]))
          break
      else:
        continue
  print("Output",Output)    
#     print("index=",index-1)
#     if test_set_node.find(a[index-1][0]) != test_set_node.find(a[index-1][1]):                                  
#       Output += a[index-1][2]
#       print("w=",a[index-1][2])
#       print("Output=",Output)
#       test_set_node.union(a[index-1][0],a[index-1][1])
   
  
  
#   for j in range(len(w)):
#     w[len(w)-j-1]
#   test_set.get()
# Out:
# test_set_node <__main__.DisjointSet object at 0x7f31cbc46dd8>
# w= [1, 2, 2, 4, 4, 6, 7, 7, 8, 8, 9, 10, 11, 14]
# ow= [4, 8, 8, 11, 7, 4, 2, 9, 14, 10, 2, 1, 6, 7]
# max_w= 14
# a[index][0]= 4
# a[index][1]= 6
# ow[i] 14
# test_set_node [[1], [2], [3], [5], [6, 4], [7], [8], [9]]
# max_w= 11
# a[index][0]= 2
# a[index][1]= 8
# ow[i] 11
# test_set_node [[1], [3], [5], [6, 4], [7], [8, 2], [9]]
# max_w= 10
# a[index][0]= 5
# a[index][1]= 6
# ow[i] 10
# test_set_node [[1], [3], [6, 4, 5], [7], [8, 2], [9]]
# max_w= 9
# a[index][0]= 4
# a[index][1]= 5
# max_w= 8
# a[index][0]= 1
# a[index][1]= 8
# ow[i] 8
# test_set_node [[3], [6, 4, 5], [7], [8, 2, 1], [9]]
# max_w= 8
# a[index][0]= 1
# a[index][1]= 8
# a[index][0]= 2
# a[index][1]= 3
# ow[i] 8
# test_set_node [[3, 8, 2, 1], [6, 4, 5], [7], [9]]
# max_w= 7
# a[index][0]= 3
# a[index][1]= 4
# ow[i] 7
# test_set_node [[6, 4, 5, 3, 8, 2, 1], [7], [9]]
# max_w= 7
# a[index][0]= 3
# a[index][1]= 4
# a[index][0]= 8
# a[index][1]= 9
# ow[i] 7
# test_set_node [[7], [9, 6, 4, 5, 3, 8, 2, 1]]
# max_w= 6
# a[index][0]= 7
# a[index][1]= 9
# ow[i] 6
# test_set_node [[9, 6, 4, 5, 3, 8, 2, 1, 7]]
# max_w= 4
# a[index][0]= 1
# a[index][1]= 2
# a[index][0]= 3
# a[index][1]= 6
# max_w= 4
# a[index][0]= 1
# a[index][1]= 2
# a[index][0]= 3
# a[index][1]= 6
# max_w= 2
# a[index][0]= 3
# a[index][1]= 9
# a[index][0]= 6
# a[index][1]= 7
# max_w= 2
# a[index][0]= 3
# a[index][1]= 9
# a[index][0]= 6
# a[index][1]= 7
# max_w= 1
# a[index][0]= 7
# a[index][1]= 8
# Output 71
